# %%
# CS194-26 (CS294-26): Project 1 starter Python code

# these are just some suggested libraries
# instead of scikit-image you could use matplotlib and opencv to read, write, and display images

import numpy as np
import skimage as sk
import skimage.io as skio
from timeit import default_timer as timer
import skimage.transform
from scipy import ndimage

# I generated my images one by one. Every time I change the name here.
pic_name = 'emir'

# name of the input file, I change the '.tif' part depending on the type of the input file
imname = 'input/' + pic_name + '.tif'

# read in the image
im = skio.imread(imname)

# convert to double (might want to do this later on to save memory)    
im = sk.img_as_float(im)
    
# compute the height of each part (just 1/3 of total)
height = np.floor(im.shape[0] / 3.0).astype(np.int)

# separate color channels
b = im[:height]
g = im[height: 2*height]
r = im[2*height: 3*height]
skio.imshow(b)
print("b shape:", b.shape)
print("g shape:", g.shape)
print("r shape:", r.shape)
# Out:
# b shape: (3209, 3702)
# g shape: (3209, 3702)
# r shape: (3209, 3702)

# %%
# # Uncomment to Manually crop the boundaries
# bound = 200 # It's a parameter we change based on the size of the image and the width of the side 
# b = b[bound:b.shape[0] - bound, bound:b.shape[1] - bound]
# g = g[bound:g.shape[0] - bound, bound:g.shape[1] - bound]
# r = r[bound:r.shape[0] - bound, bound:r.shape[1] - bound]
# print(b.shape)
# skio.imshow(g)

# %%
def ssd(img, ref):
    # this function calculates the ssd between two images to see how aligned they are.
    # They lower the return value, the more aligned they are.
    diff = img - ref
    diff = diff ** 2;
    ret = np.sum(diff)
    return ret

# %%
def edgeDetect(img, ref):
    # this error function detect the edge of each image channel using gaussian blue and subtract to get the edge.
    # We then try to use ssd to get a more accurate alignment for images that don't work too well with just ssd.
    blurred_img = ndimage.gaussian_filter(img, 3)
    filter_blurred_img = ndimage.gaussian_filter(blurred_img, 1)
    edge_img = blurred_img - filter_blurred_img
    edge_img_10 = np.where(edge_img < 0.0017, 0, 1)
    
    blurred_ref = ndimage.gaussian_filter(ref, 3)
    filter_blurred_ref = ndimage.gaussian_filter(blurred_ref, 1)
    edge_ref = blurred_ref - filter_blurred_ref
    edge_ref_10 = np.where(edge_ref < 0.0017, 0, 1)
    
    return ssd(edge_img_10, edge_ref_10)

# %%
# align the images
# functions that might be useful for aligning the images include:
# np.roll, np.sum, sk.transform.rescale (for multiscale)
def align(img, ref, maxOffset, startingPos = (0, 0)):
    # Align array with reference. return the best offsets and the aligned array.
    
    # For the exhaust search
    # the function will try -15 to +15 on x axis and y axis, 
    # remember the best displacement pair
    minErr = float('inf')
    bestImg = img
    best_offset_x = 0
    best_offset_y = 0
    for i in range(-maxOffset + startingPos[1], maxOffset + startingPos[1]):
        # i is the offset on the y axis, positive means shift downwards
        for j in range(-maxOffset + startingPos[0], maxOffset + startingPos[0]):
            # j is the offset on the x axis, positive means shift to the right
            newImg = np.roll(img, (i, j), (0 ,1))
            err = edgeDetect(newImg, ref) # USE DIFFERENT ERROR MATRIX HERE
            if err < minErr:
                minErr = err
                bestImg = newImg
                best_offset_x = j
                best_offset_y = i
    return (best_offset_x, best_offset_y), bestImg

# %%
# The recursive pyramid search function
def pyramid(img, ref, maxOffset):
    numLayer = 5
    offSetPos = (0, 0)
    for i in range(numLayer):
        scaledImg = sk.transform.rescale(img, (1/2) ** (numLayer - i - 1))
        scaledRef = sk.transform.rescale(ref, (1/2) ** (numLayer - i - 1))
        offSetPos = (offSetPos[0] * 2, offSetPos[1] * 2)
        retAlign = align(scaledImg, scaledRef, maxOffset, offSetPos)
        offSetPos = retAlign[0]
        maxOffset = 1 # after the initial search, each pixel in the upper level is split into 4 smaller pixels. 
        print(offSetPos)
    return retAlign

# %%
start = timer()
# Change the function being called to switch between exhaustive search and pyramid search
# ag = align(g, b, 15)
# ar = align(r, b, 15)
ag = pyramid(g, b, 15)
ar = pyramid(r, b, 15)

# create a color image
im_out = np.dstack([ar[1], ag[1], b])
print("best offset on the x axis in g->b:", ag[0][0])
print("best offset on the y axis in g->b:", ag[0][1])

print("best offset on the x axis in r->b:", ar[0][0])
print("best offset on the y axis in r->b:", ar[0][1])

im_out = 255 * im_out # Now scale by 255
im_out = im_out.astype(np.uint8)

# save the image, using uncommenting to switch the names
# fname = './output/' + pic_name + '_ssd.jpg'
# fname = './output/' + pic_name + '_ssd_pyramid.jpg'
# fname = './output/' + pic_name + '_ssd_pyramid_manual_crop.jpg'
fname = './output/' + pic_name + '_edge.jpg'
skio.imsave(fname, im_out)

# display the image
skio.imshow(im_out)
skio.show()

#end the timer and calculate elapsed time
end = timer()
print("elapsed time: ", end - start)
# Out:
# (2, 2)
# (3, 4)
# (5, 8)
# (9, 16)
# (18, 32)
# (2, 6)
# (4, 12)
# (8, 24)
# (15, 48)
# (30, 96)
# best offset on the x axis in g->b: 18
# best offset on the y axis in g->b: 32
# best offset on the x axis in r->b: 30
# best offset on the y axis in r->b: 96
# elapsed time:  33.86892340000122
